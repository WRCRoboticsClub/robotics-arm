# %%
import cvzone

from cvzone.HandTrackingModule import HandDetector
import cv2 as cv

# %%
cap=cv.VideoCapture(0)
cap.set(cv.CAP_PROP_FRAME_HEIGHT,1080)
cap.set(cv.CAP_PROP_FRAME_WIDTH,1920)


while True:
    sucess,img=cap.read()
    img=cv.flip(img,1)
    hsv_img=cv.cvtColor(img,cv.COLOR_BGR2HSV)
    
    cx=1280/2
    cy=720/2
    center=hsv_img[640,360]
   # print(center)
   # hsv_value=cv.cvtColor(center,cv.COLOR_BGR2HSV)
    hue_value=center[0]
    #print(hue_value)
    cv.circle(img,(640,360),5,(255,0,255),cv.FILLED)
    color='undefined'
    if hue_value<5:
        color='red'
    elif hue_value<25:
        color='orange'
    elif hue_value<33:
        color="yellow"
    elif hue_value<78:
        color="green"
    elif hue_value<131:
        color="blue"
    elif hue_value<33:
        color="voilet"
    #bgr_value=img[640,360]
    #b,g,r=int(bgr_value[0]),int(bgr_value[1]),int(bgr_value[2])
    #print(bgr_value)
    %#cv.putText(img,color,(10,50),0,1,(b,g,r),2)
            


    cv.imshow("hello",img)
    
    key=cv.waitKey(1)
    if key==ord('q'):
        cap.release()
        break
cv.destroyAllWindows()
# Out:
# [86 68 58]
# [89 70 57]
# [89 70 57]
# [89 70 57]
# [84 67 57]
# [84 67 57]
# [84 67 57]
# [81 61 50]
# [81 61 50]
# [81 61 50]
# [70 53 40]
# [70 53 40]
# [70 53 40]
# [63 50 38]
# [63 50 38]
# [63 50 38]
# [57 47 43]
# [57 47 43]
# [57 47 43]
# [58 49 45]
# [58 49 45]
# [58 49 45]
# [ 98 166 213]
# [ 98 166 213]
# [ 98 166 213]
# [108 158 190]
# [108 158 190]
# [108 158 190]
# [44 42 35]
# [44 42 35]
# [44 42 35]
# [36 35 32]
# [36 35 32]
# [36 35 32]
# [35 35 35]
# [35 35 35]
# [35 35 35]
# [35 33 29]
# [35 33 29]
# [33 30 19]
# [33 30 19]
# [38 34 27]
# [38 34 27]
# [35 34 31]
# [35 34 31]
# [36 37 24]
# [36 37 24]
# [30 26 12]
# [30 26 12]
# [44 34 25]
# [44 34 25]
# [36 32 24]
# [36 32 24]
# [38 36 23]
# [38 36 23]
# [46 33 31]
# [46 33 31]
# [45 40 31]
# [45 40 31]
# [50 40 33]
# [50 40 33]
# [38 34 20]
# [38 34 20]
# [32 37 21]
# [32 37 21]
# [45 38 32]
# [45 38 32]
# [48 38 15]
# [48 38 15]
# [43 33 19]
# [43 33 19]
# [33 35 22]
# [33 35 22]
# [39 37 26]
# [39 37 26]
# ...

# %%
cap.release()

# %%
cv.destroyAllWindows()

# %%
[255  91  38] // pure blue
