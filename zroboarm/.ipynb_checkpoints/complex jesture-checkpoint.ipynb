# %%
import cvzone

from cvzone.HandTrackingModule import HandDetector
import cv2 as cv
import math

# %%
cap=cv.VideoCapture(0)
detector=HandDetector(detectionCon=0.8,maxHands=1)
while True:
    sucess,img=cap.read()
    hands,img = detector.findHands(img)
    if hands:
        hands1=hands[0]
        lmlist1=hands1['lmList']
        bbox1=hands1["bbox"]
        if lmlist1:
            fingers=detector.fingersUp(hands1)
            # print(fingers)
            #fingers detection
#             if fingers==[0,1,1,1,1] or fingers==  [0,0,0,0,0]:
#                 print('gripper close',fingers)
#             if fingers==[1,0,0,0,0] or fingers== [1,1,1,1,1]:
#                 print('gripper open',fingers)
        
            if fingers[4]==1:
                fourf=fingers
                fourf.pop(0)
                xt,yt=lmlist1[4][0],lmlist1[4][1]
                xi,yi=lmlist1[8][0],lmlist1[8][1]
                xib,yib=lmlist1[5][0],lmlist1[5][1]
                xpb,ypb=lmlist1[17][0],lmlist1[17][1]
                x0,y0=lmlist1[0][0],lmlist1[0][1]
                
                #print(xt,yt)
                #print(lmlist1)
                cv.circle(img,(xt,yt),5,(255,0,255),cv.FILLED)
                cv.circle(img,(xi,yi),5,(255,0,255),cv.FILLED)
                cv.circle(img,(xib,yib),5,(255,0,255),cv.FILLED)
                cv.circle(img,(xpb,ypb),5,(255,0,255),cv.FILLED)
                cv.circle(img,(x0,y0),5,(255,0,255),cv.FILLED)
                
                #finding length
                length_thumb=math.hypot(xt-x0,yt-y0)
                length_roatate=math.hypot(xib-xpb,yib-ypb)
                length_index=math.hypot(xi-x0,yi-y0)
                if length_thumb <90:
                    print("decrease height",length_thumb)
                if length_thumb > 150:
                    print('increase height',length_thumb)

            
    cv.imshow("hand detection",img)
    key=cv.waitKey(1)
    if key==ord('q'):
        cap.release()
        break
cv.destroyAllWindows()
# Out:
# decrease height 78.23042886243178
# decrease height 76.00657866263946
# decrease height 74.62573282722254
# decrease height 71.58910531638176
# decrease height 71.19691004531025
# decrease height 71.11961754677819
# decrease height 70.71067811865476
# decrease height 70.71067811865476
# decrease height 71.19691004531025
# decrease height 68.87670143089025
# decrease height 67.97793759742936
# decrease height 68.8839603971781
# decrease height 68.42514157822401
# decrease height 67.11929677819934
# decrease height 66.2117814289874
# decrease height 67.97793759742936
# decrease height 66.2117814289874
# decrease height 67.11929677819934
# decrease height 67.11929677819934
# decrease height 66.2117814289874
# decrease height 67.97793759742936
# decrease height 67.97793759742936
# decrease height 67.08203932499369
# decrease height 66.64082832618455
# decrease height 66.64082832618455
# decrease height 67.97793759742936
# decrease height 67.54257916307313
# decrease height 64.88451279003334
# decrease height 66.2117814289874
# decrease height 65.30696746902278
# decrease height 65.7419196555744
# decrease height 64.88451279003334
# decrease height 66.2117814289874
# decrease height 65.7419196555744
# decrease height 66.64082832618455
# decrease height 66.64082832618455
# decrease height 66.64082832618455
# decrease height 66.64082832618455
# decrease height 66.64082832618455
# decrease height 66.2117814289874
# decrease height 66.64082832618455
# decrease height 67.53517601961218
# decrease height 67.53517601961218
# decrease height 66.64082832618455
# decrease height 73.92563831310488
# decrease height 78.26237921249263
# decrease height 78.71467461661771
# decrease height 79.84985911070852
# decrease height 81.15417426109393
# decrease height 81.54140052758476
# decrease height 81.70679286326198
# decrease height 82.63776376451628
# decrease height 82.0792300158816
# decrease height 82.0792300158816
# decrease height 81.15417426109393
# decrease height 80.77747210701756
# decrease height 89.69392398596462
# decrease height 88.76936408468859
# decrease height 89.31965069345043
# decrease height 89.15716460273958
# decrease height 88.76936408468859
# decrease height 89.31965069345043
# decrease height 89.31965069345043
# decrease height 89.31965069345043
# decrease height 89.31965069345043
# decrease height 89.88882021697692
# decrease height 88.95504482602435
# decrease height 89.88882021697692
# decrease height 89.31965069345043
# decrease height 88.3911760301898
# decrease height 89.88882021697692
# decrease height 89.88882021697692
# decrease height 89.88882021697692
# decrease height 89.5377015563835
# decrease height 88.60022573334675
# decrease height 88.60022573334675
# decrease height 89.88882021697692
# decrease height 89.88882021697692
# decrease height 88.95504482602435
# decrease height 88.60022573334675
# decrease height 88.60022573334675
# decrease height 87.66413177577246
# decrease height 88.95504482602435
# decrease height 89.31965069345043
# decrease height 89.31965069345043
# decrease height 89.69392398596462
# decrease height 89.31965069345043
# decrease height 89.88882021697692
# decrease height 88.95504482602435
# decrease height 88.95504482602435
# decrease height 88.95504482602435
# decrease height 88.60022573334675
# decrease height 88.95504482602435
# decrease height 89.31965069345043
# decrease height 89.31965069345043
# decrease height 89.31965069345043
# decrease height 89.31965069345043
# decrease height 88.95504482602435
# decrease height 89.31965069345043
# decrease height 89.69392398596462
# decrease height 89.69392398596462
# decrease height 89.69392398596462
# decrease height 89.31965069345043
# decrease height 89.31965069345043
# decrease height 88.3911760301898
# decrease height 89.31965069345043
# decrease height 87.46427842267951
# decrease height 87.46427842267951
# decrease height 89.69392398596462
# decrease height 88.76936408468859
# decrease height 89.69392398596462
# decrease height 89.69392398596462
# decrease height 85.23496934944014
# decrease height 73.40980860893181
# decrease height 74.32361670424818
# decrease height 70.26378868236469
# decrease height 69.35416353759881
# decrease height 64.62197768561404
# decrease height 65.55150646628954
# decrease height 64.25729530566937
# decrease height 64.25729530566937
# decrease height 64.25729530566937
# decrease height 63.90618123468183
# decrease height 65.19202405202648
# decrease height 65.19202405202648
# decrease height 61.35144660071187
# decrease height 61.35144660071187
# decrease height 65.7875368135941
# decrease height 63.90618123468183
# decrease height 65.19202405202648
# decrease height 65.7875368135941
# decrease height 66.73080248281148
# decrease height 66.09841147864296
# decrease height 65.45991139621256
# decrease height 68.9492567037528
# decrease height 67.06713054842886
# decrease height 68.00735254367721
# decrease height 68.35202996254024
# decrease height 67.06713054842886
# decrease height 65.19202405202648
# decrease height 65.7875368135941
# decrease height 65.7875368135941
# decrease height 67.06713054842886
# decrease height 67.06713054842886
# decrease height 65.55150646628954
# decrease height 63.56886030125127
# decrease height 65.7875368135941
# decrease height 64.8459713474939
# decrease height 64.8459713474939
# decrease height 62.96824596572466
# decrease height 64.25729530566937
# decrease height 69.6419413859206
# decrease height 69.6419413859206
# decrease height 79.71198153351854
# decrease height 79.37883848986453
# decrease height 87.93179174792243
# decrease height 86.40023148117139
# decrease height 84.48076704197234
# decrease height 84.71717653463199
# decrease height 82.60750571225353
# decrease height 77.10382610480494
# decrease height 74.67261881037788
# decrease height 72.83543093852057
# decrease height 66.2872536767062
# decrease height 66.2872536767062
# decrease height 59.481089431852205
# decrease height 56.64803615307419
# decrease height 53.75872022286245
# decrease height 53.48831648126533
# decrease height 55.362442142665635
# decrease height 54.230987451824994
# decrease height 51.86520991955976
# decrease height 54.120236510939236
# decrease height 52.20153254455275
# decrease height 51.62363799656123

# %%
cap.release()
cv.destroyAllWindows()
