# %%
import cvzone

from cvzone.HandTrackingModule import HandDetector
import cv2 as cv
import math
import serial

# %%
ser=serial.Serial('COM3',9600,timeout=1)

# %%
cap=cv.VideoCapture(0)
detector=HandDetector(detectionCon=0.8,maxHands=1)

while True:
    sucess,img=cap.read()
    img=cv.flip(img,1)
    hands,img = detector.findHands(img)
    if hands:
        hands1=hands[0]
        lmlist1=hands1['lmList']
        bbox1=hands1["bbox"]
        if lmlist1:
            fingers=detector.fingersUp(hands1)
            #print(fingers)
            #fingers detection
            try:
                if fingers==[0,1,1,0,0] or fingers==  [1,1,1,0,0]:
                    print('gripper close',fingers)
                    ser.write(b'f')
                if fingers==[1,1,1,1,0] or fingers== [0,1,1,1,0]:
                    print('gripper open',fingers)
                    ser.write(b'e')
            except:
                print("error in thumb")
        
            if fingers[4]==1:
                
                xt,yt=lmlist1[4][0],lmlist1[4][1]
                xi,yi=lmlist1[8][0],lmlist1[8][1]
                xib,yib=lmlist1[5][0],lmlist1[5][1]
                xpb,ypb=lmlist1[17][0],lmlist1[17][1]
                x0,y0=lmlist1[0][0],lmlist1[0][1]
                
                #print(xt,yt)
                #print(lmlist1)
                cv.circle(img,(xt,yt),5,(255,0,255),cv.FILLED)
                cv.circle(img,(xi,yi),5,(255,0,255),cv.FILLED)
                cv.circle(img,(xib,yib),5,(255,0,255),cv.FILLED)
                cv.circle(img,(xpb,ypb),5,(255,0,255),cv.FILLED)
                cv.circle(img,(x0,y0),5,(255,0,255),cv.FILLED)
                cv.line(img,(x0,y0),(xi,yi),(255,0,255),2)
                
                #finding length
                length_thumb=math.hypot(xt-x0,yt-y0)
                length_roatate=math.hypot(xib-xpb,yib-ypb)
                length_index=math.hypot(xi-x0,yi-y0)
                #print(length_roatate)
                try:
                    if length_thumb <70:
                        print("decrease height",length_thumb)
                        cv.circle(img,(xt,yt),5,(255,0,0),cv.FILLED)
                        ser.write(b'a')
                    if length_thumb > 105:
                        print('increase height',length_thumb)
                        cv.circle(img,(xt,yt),5,(255,0,0),cv.FILLED)
                        ser.write(b'b')
                    if length_index<80:
                        print("contrcat")
                        cv.circle(img,(xi,yi),5,(255,0,0),cv.FILLED)
                        #ser.write(b'd')
                    if length_index>150:
                        print('expand')
                        cv.circle(img,(xi,yi),5,(255,0,0),cv.FILLED)
                        #ser.write(b'c')
#                     if length_roatate<30:
#                         print("rotate left")
#                         (img,(xpb,ypb),5,(255,0,0),cv.FILLED)
#                     if length_roatate>80:
#                         print("come to normal")
                except:
                    print('error occured')

            
    cv.imshow("hand detection",img)
    key=cv.waitKey(1)
    if key==ord('q'):
        cap.release()
        break
cv.destroyAllWindows()
ser.close()
# Out:
# increase height 125.59060474414477
# expand
# gripper close [1, 1, 1, 0, 0]
# gripper close [1, 1, 1, 0, 0]
# gripper close [1, 1, 1, 0, 0]
# gripper close [1, 1, 1, 0, 0]
# gripper close [1, 1, 1, 0, 0]
# gripper close [1, 1, 1, 0, 0]
# gripper close [1, 1, 1, 0, 0]
# gripper close [1, 1, 1, 0, 0]
# gripper close [1, 1, 1, 0, 0]
# gripper close [1, 1, 1, 0, 0]
# gripper close [1, 1, 1, 0, 0]
# gripper close [1, 1, 1, 0, 0]
# gripper close [1, 1, 1, 0, 0]
# gripper close [1, 1, 1, 0, 0]
# gripper close [0, 1, 1, 0, 0]
# gripper close [1, 1, 1, 0, 0]
# gripper close [0, 1, 1, 0, 0]
# gripper close [0, 1, 1, 0, 0]
# gripper close [0, 1, 1, 0, 0]
# gripper close [1, 1, 1, 0, 0]
# gripper close [1, 1, 1, 0, 0]
# gripper close [1, 1, 1, 0, 0]
# gripper close [1, 1, 1, 0, 0]
# gripper close [1, 1, 1, 0, 0]
# gripper close [1, 1, 1, 0, 0]
# gripper close [1, 1, 1, 0, 0]
# gripper close [1, 1, 1, 0, 0]
# gripper close [1, 1, 1, 0, 0]
# gripper close [1, 1, 1, 0, 0]
# gripper close [1, 1, 1, 0, 0]
# gripper close [1, 1, 1, 0, 0]
# gripper close [1, 1, 1, 0, 0]
# gripper close [1, 1, 1, 0, 0]
# gripper close [1, 1, 1, 0, 0]
# gripper close [1, 1, 1, 0, 0]
# gripper close [1, 1, 1, 0, 0]
# gripper close [1, 1, 1, 0, 0]
# gripper close [1, 1, 1, 0, 0]
# gripper close [1, 1, 1, 0, 0]
# gripper open [1, 1, 1, 1, 0]
# gripper close [1, 1, 1, 0, 0]
# gripper close [1, 1, 1, 0, 0]
# increase height 181.1767093199344
# expand
# increase height 181.7470770053813
# expand
# increase height 184.39088914585776
# expand
# increase height 181.5736765062601
# expand
# increase height 178.94133116750865
# expand
# increase height 181.1767093199344
# expand
# increase height 178.03651310896873
# expand
# increase height 177.61193653580833
# expand
# increase height 171.39719951037708
# expand
# increase height 170.985379491932
# expand
# increase height 170.985379491932
# expand
# increase height 162.87418457201866
# expand
# increase height 159.65587994182988
# expand
# increase height 160.55217220579732
# expand
# increase height 158.3161394173064
# expand
# increase height 160.11246047700348
# expand
# increase height 162.04937519163718
# expand
# increase height 166.5172663719892
# expand
# increase height 165.60495161679194
# expand
# increase height 176.7823520603796
# expand
# increase height 175.69291391516052
# expand
# increase height 187.4593289223025
# expand
# increase height 186.72439583514523
# expand
# increase height 201.4671189052943
# expand
# increase height 200.5243127403757
# expand
# increase height 200.5243127403757
# expand
# increase height 198.97989848223364
# expand
# increase height 198.97989848223364
# expand
# increase height 199.6722314193939
# expand
# increase height 201.89601283829256
# expand
# increase height 193.54586019855861
# expand
# increase height 193.1553778697347
# expand
# increase height 193.1553778697347
# expand
# increase height 180.2720166858961
# expand
# increase height 139.9428454762872
# expand
# increase height 138.92443989449805
# expand
# increase height 106.07544484940895
# expand
# increase height 105.41821474489122
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# increase height 106.17438485811914
# expand
# expand
# expand
# expand
# expand
# expand
# increase height 107.5174404457249
# expand
# increase height 105.38026380684383
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# expand
# increase height 118.15244390193544
# expand
# increase height 121.49074038789952
# expand
# increase height 125.93649193144932
# increase height 123.42204017111368
# increase height 123.71337841963576
# increase height 123.17467272130257
# increase height 125.93649193144932
# increase height 126.05157674539419
# increase height 125.19584657647394
# increase height 131.60927019021113
# increase height 129.71121771072848
# increase height 131.94695904036593
# increase height 132.3782459469833
# increase height 125.23977004130916
# increase height 124.32618388738553
# increase height 125.67020331009256
# increase height 120.3536455617361
# increase height 120.83045973594572
# expand
# increase height 119.70797801316336
# expand
# increase height 118.72657663724664
# expand
# increase height 123.54756169184401
# expand
# increase height 122.98373876248843
# increase height 140.9432509913121
# expand
# increase height 157.87653403846943
# expand
# increase height 182.92348127017482
# expand
# increase height 184.39631232755173
# expand
# increase height 187.92817777012579
# expand
# increase height 186.45374761586316
# expand
# increase height 187.55265927200287
# expand
# increase height 189.04232330353963
# expand
# increase height 187.55265927200287
# expand
# increase height 185.53975315279473
# expand
# increase height 188.95766721676048
# expand
# increase height 190.2761151589973
# expand
# increase height 187.040102651811
# expand
# increase height 186.9786084021378
# expand
# increase height 186.55294154743314
# expand
# increase height 185.23768515072737
# expand
# increase height 190.8952592391964
# expand
# increase height 186.93849255838134
# expand
# increase height 206.92993983471797
# expand
# increase height 202.51419703319567
# expand
# increase height 199.7298175035465
# expand
# increase height 196.8146336022807
# expand
# increase height 199.40160480798542
# expand
# increase height 196.81717404738845
# expand
# increase height 185.23498589629335
# expand
# increase height 177.2596964907703
# expand
# increase height 173.04623659588788
# expand
# increase height 161.02794788483146
# expand
# increase height 150.20652449211386
# expand
# increase height 147.00340132119393
# expand
# increase height 149.40214188558343
# expand
# increase height 135.80132547217644
# expand
# increase height 138.80922159568507
# expand
# increase height 122.78843593759146
# expand
# expand
# expand
# decrease height 57.584720195551874
# decrease height 57.245087125446844
# decrease height 56.92099788303083
# decrease height 55.54277630799526
# decrease height 54.817880294662984
# decrease height 57.87054518492115
# decrease height 56.71860364994893
# decrease height 56.71860364994893
# decrease height 56.71860364994893
# decrease height 57.706152185014034
# decrease height 57.55866572463264
# decrease height 56.71860364994893
# decrease height 56.32051136131489
# decrease height 57.3149195236284
# decrease height 55.731499172371095
# decrease height 55.44366510251645
# decrease height 56.71860364994893
# decrease height 56.71860364994893
# decrease height 55.731499172371095
# decrease height 55.44366510251645
# decrease height 57.0701322935211
# increase height 107.71258050942797
# increase height 108.4665847162157
# increase height 109.71326264403953
# increase height 109.71326264403953
# increase height 109.71326264403953
# increase height 109.71326264403953
# increase height 108.97706180660222
# increase height 109.71326264403953
# increase height 111.19802156513397
# increase height 111.19802156513397
# increase height 109.34349546269316
# increase height 107.05606008068857
# increase height 107.05606008068857
# increase height 106.4048871058092
# increase height 105.75916035975324
# increase height 105.75916035975324
# increase height 105.89145385724005
# increase height 105.11898020814318
# increase height 105.11898020814318
# increase height 106.66770832824712
# increase height 106.04244433244644
# increase height 107.00467279516349
# increase height 106.21205204683694
# increase height 108.2266141020775
# increase height 109.04127658827184
# increase height 109.55363982999378
# increase height 109.55363982999378
# increase height 109.29318368498559
# increase height 111.51681487560519
# increase height 111.51681487560519
# increase height 112.05802068571441
# increase height 111.22050170719426
# increase height 113.20777358467925
# increase height 111.83022847155415
# increase height 112.6809655620682
# increase height 110.98198051936178
# increase height 112.36102527122117
# increase height 113.74093370462545
# increase height 113.20777358467925
# increase height 114.0570032922135
# increase height 114.58621208504974
# increase height 113.20777358467925
# increase height 113.20777358467925
# increase height 114.0570032922135
# increase height 113.53413583587978
# increase height 114.73883387938018
# increase height 115.24755962709145
# increase height 115.24755962709145
# increase height 115.76268828944843
# increase height 115.76268828944843
# increase height 119.70797801316336
# expand
# increase height 119.70797801316336
# expand
# increase height 122.80065146407001
# expand
# increase height 124.53112060846478
# expand
# increase height 122.29881438509533
# expand
# increase height 123.664869708418
# expand
# increase height 123.664869708418
# expand
# increase height 125.53883861180172
# expand
# increase height 125.53883861180172
# expand
# increase height 126.05157674539419
# expand
# increase height 128.2809416865966
# expand
# increase height 126.90941651429968
# expand
# increase height 127.94530081249565
# expand
# increase height 128.79829191413992
# expand
# increase height 130.17296186228538
# expand
# increase height 131.54847015454038
# expand
# increase height 131.54847015454038
# expand
# increase height 132.07573584879245
# expand
# increase height 131.88252348207476
# expand
# increase height 134.1118935814419
# expand
# increase height 136.0036764208968
# expand
# increase height 138.7984149765407
# expand
# increase height 138.7984149765407
# expand
# increase height 140.42791745233566
# expand
# increase height 142.21462653327893
# expand
# increase height 135.1184665395519
# increase height 129.29423807734048

# %%
cap.release()
cv.destroyAllWindows()

# %%
ser.close()

# %%
ser.write(b'b')
# Out:
# 1

# %%
ser.write(b'z')
# Out:
# 1
